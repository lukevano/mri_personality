# %%
#Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
#Data without duplicates
df = pd.read_csv("master_dup_removed.csv")

# %%
df
# Out:
#      participant_id    age     sex   BMI    handedness education_category  \
# 0          sub-0001  26.25       F  24.0         right            applied
# 1          sub-0002  21.00       F  23.0         right           academic
# 2          sub-0003  23.00       M  22.0         right           academic
# 3          sub-0004  23.50       F  22.0         right            applied
# 4          sub-0005  21.75       M  19.0  ambidextrous            applied
# ...             ...    ...     ...   ...           ...                ...
# 1357       sub-1358  22.25    male  21.0         right             medium
# 1358       sub-1359  25.25    male  30.0         right             medium
# 1359       sub-1360  20.75    male  22.0         right               high
# 1360       sub-1361  24.25  female  35.0         right             medium
# 1361       sub-1362  20.50    male  19.0          left               high
#
#       NEO_N  NEO_E  NEO_O  NEO_A  ...  CC_Mid_Anterior  CC_Anterior  \
# ...

# %% [markdown]
# # Plot

# %%
df[["NEO_N","NEO_E","NEO_O","NEO_A","NEO_C"]].plot(figsize=(15,5));

# %%
df[["NEO_N"]].plot(figsize=(15,20));

# %%
features = df.copy()

# %%
features.drop(columns=["NEO_N","NEO_E","NEO_O","NEO_A","NEO_C"], inplace = True)

# %%
features
# Out:
#      participant_id    age     sex   BMI    handedness education_category  \
# 0          sub-0001  26.25       F  24.0         right            applied
# 1          sub-0002  21.00       F  23.0         right           academic
# 2          sub-0003  23.00       M  22.0         right           academic
# 3          sub-0004  23.50       F  22.0         right            applied
# 4          sub-0005  21.75       M  19.0  ambidextrous            applied
# ...             ...    ...     ...   ...           ...                ...
# 1357       sub-1358  22.25    male  21.0         right             medium
# 1358       sub-1359  25.25    male  30.0         right             medium
# 1359       sub-1360  20.75    male  22.0         right               high
# 1360       sub-1361  24.25  female  35.0         right             medium
# 1361       sub-1362  20.50    male  19.0          left               high
#
#       lh_bankssts_thickness  lh_caudalanteriorcingulate_thickness  \
# ...

# %% [markdown]
# # Outliers

# %% [markdown]
# ## Analysis

# %%
features.describe().T.iloc[:50]
# Out:
#                                         count          mean            std  \
# age                                    1353.0  2.261160e+01       1.768582
# BMI                                    1353.0  2.345233e+01       4.461636
# lh_bankssts_thickness                  1362.0  2.612562e+00       0.150417
# lh_caudalanteriorcingulate_thickness   1362.0  2.834280e+00       0.215096
# lh_caudalmiddlefrontal_thickness       1362.0  2.668168e+00       0.148599
# lh_cuneus_thickness                    1362.0  1.883604e+00       0.170207
# lh_entorhinal_thickness                1362.0  3.466649e+00       0.280335
# lh_fusiform_thickness                  1362.0  2.797416e+00       0.117457
# lh_inferiorparietal_thickness          1362.0  2.548996e+00       0.110110
# lh_inferiortemporal_thickness          1362.0  2.822752e+00       0.137308
# lh_isthmuscingulate_thickness          1362.0  2.525356e+00       0.183250
# ...

# %%
features.describe().T.iloc[50:100]
# Out:
#                                         count          mean          std  \
# rh_lingual_thickness                   1362.0      2.062628     0.159799
# rh_medialorbitofrontal_thickness       1362.0      2.635324     0.169555
# rh_middletemporal_thickness            1362.0      2.926887     0.154000
# rh_parahippocampal_thickness           1362.0      2.847018     0.243536
# rh_paracentral_thickness               1362.0      2.513228     0.144201
# rh_parsopercularis_thickness           1362.0      2.733642     0.143012
# rh_parsorbitalis_thickness             1362.0      2.800231     0.191009
# rh_parstriangularis_thickness          1362.0      2.616477     0.158957
# rh_pericalcarine_thickness             1362.0      1.600642     0.166769
# rh_postcentral_thickness               1362.0      2.099117     0.115484
# rh_posteriorcingulate_thickness        1362.0      2.640957     0.156866
# rh_precentral_thickness                1362.0      2.646363     0.127419
# ...

# %%
features.describe().T.iloc[100:]
# Out:
#                                count           mean           std  \
# Right-Hippocampus             1362.0    4284.309398    432.929091
# Right-Amygdala                1362.0    1773.850073    250.437994
# Right-Accumbens-area          1362.0     606.135977    108.732890
# Right-VentralDC               1362.0    4218.446843    427.122458
# Right-vessel                  1362.0      20.835683     20.315928
# Right-choroid-plexus          1362.0     453.530764    149.605599
# 5th-Ventricle                 1362.0       0.151248      0.745283
# WM-hypointensities            1362.0     961.255874    470.818449
# Left-WM-hypointensities       1362.0       0.000000      0.000000
# Right-WM-hypointensities      1362.0       0.000000      0.000000
# non-WM-hypointensities        1362.0       0.018943      0.242676
# Left-non-WM-hypointensities   1362.0       0.000000      0.000000
# Right-non-WM-hypointensities  1362.0       0.000000      0.000000
# ...

# %% [markdown]
# ## Conclusion 1
#
# Remove features with 0 values, meaning:
#
# Left-WM-hypointensities
# Right-WM-hypointensities
# Left-non-WM-hypointensities
# Right-non-WM-hypointensities

# %% [markdown]
# # Null values

# %% [markdown]
# ## Analysis

# %%
features.isnull().sum()[0:50]
# Out:
# participant_id                           0
# age                                      9
# sex                                      8
# BMI                                      9
# handedness                               9
# education_category                       1
# lh_bankssts_thickness                    0
# lh_caudalanteriorcingulate_thickness     0
# lh_caudalmiddlefrontal_thickness         0
# lh_cuneus_thickness                      0
# lh_entorhinal_thickness                  0
# lh_fusiform_thickness                    0
# lh_inferiorparietal_thickness            0
# lh_inferiortemporal_thickness            0
# lh_isthmuscingulate_thickness            0
# lh_lateraloccipital_thickness            0
# lh_lateralorbitofrontal_thickness        0
# lh_lingual_thickness                     0
# lh_medialorbitofrontal_thickness         0
# lh_middletemporal_thickness              0
# lh_parahippocampal_thickness             0
# lh_paracentral_thickness                 0
# ...

# %%
features.isnull().sum()[50:100]
# Out:
# rh_inferiortemporal_thickness            0
# rh_isthmuscingulate_thickness            0
# rh_lateraloccipital_thickness            0
# rh_lateralorbitofrontal_thickness        0
# rh_lingual_thickness                     0
# rh_medialorbitofrontal_thickness         0
# rh_middletemporal_thickness              0
# rh_parahippocampal_thickness             0
# rh_paracentral_thickness                 0
# rh_parsopercularis_thickness             0
# rh_parsorbitalis_thickness               0
# rh_parstriangularis_thickness            0
# rh_pericalcarine_thickness               0
# rh_postcentral_thickness                 0
# rh_posteriorcingulate_thickness          0
# rh_precentral_thickness                  0
# rh_precuneus_thickness                   0
# rh_rostralanteriorcingulate_thickness    0
# rh_rostralmiddlefrontal_thickness        0
# rh_superiorfrontal_thickness             0
# rh_superiorparietal_thickness            0
# rh_superiortemporal_thickness            0
# ...

# %%
features.isnull().sum()[100:]
# Out:
# Right-Thalamus-Proper           0
# Right-Caudate                   0
# Right-Putamen                   0
# Right-Pallidum                  0
# Right-Hippocampus               0
# Right-Amygdala                  0
# Right-Accumbens-area            0
# Right-VentralDC                 0
# Right-vessel                    0
# Right-choroid-plexus            0
# 5th-Ventricle                   0
# WM-hypointensities              0
# Left-WM-hypointensities         0
# Right-WM-hypointensities        0
# non-WM-hypointensities          0
# Left-non-WM-hypointensities     0
# Right-non-WM-hypointensities    0
# Optic-Chiasm                    0
# CC_Posterior                    0
# CC_Mid_Posterior                0
# CC_Central                      0
# CC_Mid_Anterior                 0
# CC_Anterior                     0
# CortexVol                       0
# CerebralWhiteMatterVol          0
# SubCortGrayVol                  0
# TotalGrayVol                    0
# ...

# %% [markdown]
# ## Conclusion:
#
# Null values:
#
# age                                      9;
# sex                                      8;
# BMI                                      9;
# handedness                               9;
# education_category                       1

# %% [markdown]
# # Classifiers: Sex ; Handedness	and Education

# %% [markdown]
# ## Analysis

# %%
features["sex"].unique()
# Out:
# array(['F', 'M', nan, 'female', 'male'], dtype=object)

# %%
features["sex"].value_counts()
# Out:
# female    483
# male      445
# F         244
# M         182
# Name: sex, dtype: int64

# %%
features["sex"].value_counts().plot(kind="bar");

# %%
features["handedness"].value_counts()
# Out:
# right           1200
# left             148
# ambidextrous       5
# Name: handedness, dtype: int64

# %%
features["handedness"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
features["education_category"].value_counts()
# Out:
# high        439
# medium      400
# academic    223
# applied     210
# low          89
# Name: education_category, dtype: int64

# %%
features["education_category"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion:
#
# Sex variable must be binary

# %% [markdown]
# ## Question:
#
# Should we create subgroups for the other variables?

# %% [markdown]
# # Correlation

# %% [markdown]
# ## Analysis

# %%
sns.heatmap(features.corr(),cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Action :

# %% [markdown]
# Keep investigating how to deal with high number of features
